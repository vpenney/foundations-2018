# %%
import pandas as pd

# %% [markdown]
# In jupyter notebook, you can type !pip install pandas--the exclamation mark functions like the terminal command line

# %%
type(pd.read_csv("countries.csv"))
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Why is this better than Excel? In Excel, if you type an equation wrong, no one knows or can proofread.
# With pandas, you can see all the code that you want to run and you can drop a new file in.

# %%
pd.read_csv("countries.csv")
# Out:
#                     Country   Continent  GDP_per_capita  life_expectancy  \
# 0               Afghanistan        Asia             663           54.863
# 1                   Albania      Europe            4195           74.200
# 2                   Algeria      Africa            5098           68.963
# 3                    Angola      Africa            2446           45.234
# 4       Antigua and Barbuda  N. America           12738           73.544
# 5                 Argentina  S. America           10571           73.822
# 6                   Armenia      Europe            2114           71.494
# 7                 Australia     Oceania           29241           79.930
# 8                   Austria      Europe           32008           78.330
# 9                Azerbaijan      Europe            2533           66.851
# 10                  Bahamas  N. America           22728           72.370
# 11                  Bahrain        Asia           22015           74.497
# ...

# %%
df = pd.read_csv("countries.csv")

# %%
df.head()
# Out:
#                Country   Continent  GDP_per_capita  life_expectancy  \
# 0          Afghanistan        Asia             663           54.863
# 1              Albania      Europe            4195           74.200
# 2              Algeria      Africa            5098           68.963
# 3               Angola      Africa            2446           45.234
# 4  Antigua and Barbuda  N. America           12738           73.544
#
#    Population
# 0    22856302
# 1     3071856
# 2    30533827
# 3    13926373
# 4       77656

# %%
df.tail()
# Out:
#                 Country Continent  GDP_per_capita  life_expectancy  Population
# 183             Vietnam      Asia            1577           73.777    78758010
# 184  West Bank and Gaza      Asia            7586           70.929     3198560
# 185         Yemen, Rep.      Asia            2217           60.404    17723186
# 186              Zambia    Africa            1035           41.802    10201562
# 187            Zimbabwe    Africa             745           43.976    12509477

# %%
df.tail(3)
# Out:
#          Country Continent  GDP_per_capita  life_expectancy  Population
# 185  Yemen, Rep.      Asia            2217           60.404    17723186
# 186       Zambia    Africa            1035           41.802    10201562
# 187     Zimbabwe    Africa             745           43.976    12509477

# %%
df.head(3)
# Out:
#        Country Continent  GDP_per_capita  life_expectancy  Population
# 0  Afghanistan      Asia             663           54.863    22856302
# 1      Albania    Europe            4195           74.200     3071856
# 2      Algeria    Africa            5098           68.963    30533827

# %%
df.shape
# Out:
# (188, 5)

# %% [markdown]
# df.shape tells us how many rows and columns we have

# %% [markdown]
# data types: string, int, and float

# %%
df.dtypes
# Out:
# Country             object
# Continent           object
# GDP_per_capita       int64
# life_expectancy    float64
# Population           int64
# dtype: object

# %% [markdown]
# GDP and populationa are 64-bit integers
# float 64 vs float are essentially the same, just has to do with the decimal points

# %% [markdown]
# *The three things that you should do when you read in a dataset:

# %%
df = pd.read_csv("countries.csv")

# %% [markdown]
# ### 1) Look at .head() to make sure your data looks kind of right

# %%
df.head(3)
# Out:
#        Country Continent  GDP_per_capita  life_expectancy  Population
# 0  Afghanistan      Asia             663           54.863    22856302
# 1      Albania    Europe            4195           74.200     3071856
# 2      Algeria    Africa            5098           68.963    30533827

# %% [markdown]
# ### 2) Look at .shape to see how many rows and columns your data has (and make sure it looks right)

# %%
df.dtypes
# Out:
# Country             object
# Continent           object
# GDP_per_capita       int64
# life_expectancy    float64
# Population           int64
# dtype: object

# %% [markdown]
# ### Look at .dtypes to see that data types of all your columbs and the names of your columns

# %%
df.head(3)
# Out:
#        Country Continent  GDP_per_capita  life_expectancy  Population
# 0  Afghanistan      Asia             663           54.863    22856302
# 1      Albania    Europe            4195           74.200     3071856
# 2      Algeria    Africa            5098           68.963    30533827

# %%
# let's get the biggest country
df.sort_values(by="Population")
# sort_values always sorts in ascending order (aka smallest first)
# Out:
#                               Country   Continent  GDP_per_capita  \
# 64                          Greenland  N. America           33204
# 4                 Antigua and Barbuda  N. America           12738
# 146                        Seychelles      Africa           15230
# 87                           Kiribati     Oceania            3501
# 169                             Tonga     Oceania            4886
# 65                            Grenada  N. America            8655
# 111             Micronesia, Fed. Sts.     Oceania            5530
# 140  Saint Vincent and the Grenadines  N. America            5893
# 142             Sao Tome and Principe      Africa            1320
# 139                       Saint Lucia  N. America            8676
# 141                             Samoa     Oceania            4090
# 181                           Vanuatu     Oceania            3762
# 16                             Belize  N. America            6545
# ...

# %%
# if we want to sort in ascending
df.sort_values(by="Population", ascending=False).head(3)
# Out:
#            Country   Continent  GDP_per_capita  life_expectancy  Population
# 34           China        Asia            3407           72.124  1269116737
# 75           India        Asia            1648           62.129  1053898107
# 178  United States  N. America           39758           76.800   282496310

# %%
# when you want to grab a specific column
df['life_expectancy']
# Out:
# 0      54.863
# 1      74.200
# 2      68.963
# 3      45.234
# 4      73.544
# 5      73.822
# 6      71.494
# 7      79.930
# 8      78.330
# 9      66.851
# 10     72.370
# 11     74.497
# 12     65.309
# 13     73.118
# 14     68.990
# 15     77.910
# 16     70.425
# 17     55.261
# 18     60.307
# 19     62.994
# 20     74.882
# 21     50.567
# 22     70.261
# 23     75.927
# 24     71.590
# 25     50.589
# 26     48.251
# 27     62.030
# 28     51.960
# 29     79.410
#         ...
# 158    67.851
# 159    48.689
# 160    79.840
# 161    79.990
# 162    73.316
# 163    76.020
# 164    63.570
# 165    50.010
# 166    70.921
# 167    59.468
# 168    53.585
# 169    70.810
# 170    68.533
# 171    73.159
# 172    70.010
# 173    63.925
# 174    48.126
# 175    67.790
# 176    74.163
# 177    78.040
# 178    76.800
# 179    74.777
# 180    66.999
# 181    67.438
# 182    72.432
# 183    73.777
# 184    70.929
# 185    60.404
# 186    41.802
# 187    43.976
# ...

# %%
df['Continent']
# Out:
# 0            Asia
# 1          Europe
# 2          Africa
# 3          Africa
# 4      N. America
# 5      S. America
# 6          Europe
# 7         Oceania
# 8          Europe
# 9          Europe
# 10     N. America
# 11           Asia
# 12           Asia
# 13     N. America
# 14         Europe
# 15         Europe
# 16     N. America
# 17         Africa
# 18           Asia
# 19     S. America
# 20         Europe
# 21         Africa
# 22     S. America
# 23           Asia
# 24         Europe
# 25         Africa
# 26         Africa
# 27           Asia
# 28         Africa
# 29     N. America
#           ...
# 158    S. America
# 159        Africa
# 160        Europe
# 161        Europe
# 162          Asia
# 163          Asia
# 164          Asia
# 165        Africa
# 166          Asia
# 167          Asia
# 168        Africa
# 169       Oceania
# 170    N. America
# 171        Africa
# 172          Asia
# 173          Asia
# 174        Africa
# 175        Europe
# 176          Asia
# ...

# %%
type(df['Continent'])
# data frames are beautiful, but when things look ugly, they're probably a series
# if you pull out a single column, it's called a SERIES
# A DATAFRAME is made up of many SERIES
# series = ugly
# Out:
# pandas.core.series.Series

# %%
### If you have a column that's a 
It tells you how many times each value appears

# %%
df['Continent'].value_counts()
# Out:
# Africa        54
# Asia          48
# Europe        42
# N. America    22
# S. America    12
# Oceania       10
# Name: Continent, dtype: int64

# %% [markdown]
# ### You can do 'df.colname' or 'df['colname']', they're the same (at least for now)

# %%
df.Continent
# Out:
# 0            Asia
# 1          Europe
# 2          Africa
# 3          Africa
# 4      N. America
# 5      S. America
# 6          Europe
# 7         Oceania
# 8          Europe
# 9          Europe
# 10     N. America
# 11           Asia
# 12           Asia
# 13     N. America
# 14         Europe
# 15         Europe
# 16     N. America
# 17         Africa
# 18           Asia
# 19     S. America
# 20         Europe
# 21         Africa
# 22     S. America
# 23           Asia
# 24         Europe
# 25         Africa
# 26         Africa
# 27           Asia
# 28         Africa
# 29     N. America
#           ...
# 158    S. America
# 159        Africa
# 160        Europe
# 161        Europe
# 162          Asia
# 163          Asia
# 164          Asia
# 165        Africa
# 166          Asia
# 167          Asia
# 168        Africa
# 169       Oceania
# 170    N. America
# 171        Africa
# 172          Asia
# 173          Asia
# 174        Africa
# 175        Europe
# 176          Asia
# ...

# %%
df.head(3)
# Out:
#        Country Continent  GDP_per_capita  life_expectancy  Population
# 0  Afghanistan      Asia             663           54.863    22856302
# 1      Albania    Europe            4195           74.200     3071856
# 2      Algeria    Africa            5098           68.963    30533827

# %%
df.life_expectancy.median()
# Out:
# 70.04150000000001

# %%
df.life_expectancy.mean()
# Out:
# 66.50153603526596

# %%
# Is the mean gdp higher or lower than the median gdp?
df.GDP_per_capita.median()
# Out:
# 5290.5

# %%
df.GDP_per_capita.mean()
# Out:
# 9977.558510638299

# %%
df.Population.mean()
# Out:
# 32526821.05319149

# %%
df.Population.median()
# Out:
# 6888970.5

# %%
df.Population.sum()
# Out:
# 6115042358

# %%
df.life_expectancy.max()
# Out:
# 81.35

# %%
df.sort_values(by='life_expectancy', ascending=False).head(3)
# Out:
#               Country Continent  GDP_per_capita  life_expectancy  Population
# 83              Japan      Asia           28559           81.350   125720310
# 72   Hong Kong, China      Asia           29972           80.361     6783317
# 161       Switzerland    Europe           34386           79.990     7167908

# %%
# find documentation
df.sort_values?

# %%
# Why would we want to create a dataframe manually? 
# importing JSON data

# %%
df.head(3)
# Out:
#        Country Continent  GDP_per_capita  life_expectancy  Population
# 0  Afghanistan      Asia             663           54.863    22856302
# 1      Albania    Europe            4195           74.200     3071856
# 2      Algeria    Africa            5098           68.963    30533827

# %%
# Eitehr one of these will work ( ... for now)
df['life_expectancy'].describe()
df.life_expectancy.describe()
# Out:
# count    188.000000
# mean      66.501536
# std       10.298458
# min       38.123000
# 25%       59.663750
# 50%       70.041500
# 75%       74.134500
# max       81.350000
# Name: life_expectancy, dtype: float64

# %%
# df.describe() will take all of your numeric columns and describe them for you
df.describe()
# Out:
#        GDP_per_capita  life_expectancy    Population
# count      188.000000       188.000000  1.880000e+02
# mean      9977.558511        66.501536  3.252682e+07
# std      11953.393378        10.298458  1.237952e+08
# min        292.000000        38.123000  5.619600e+04
# 25%       1732.500000        59.663750  2.003170e+06
# 50%       5290.500000        70.041500  6.888970e+06
# 75%      12701.250000        74.134500  2.218517e+07
# max      63924.000000        81.350000  1.269117e+09

# %%
df.life_expectancy.median()
# Out:
# 70.04150000000001

# %% [markdown]
# ### Do analysis based on continent
# Your best friend will be df.groupby()

# %%
df.groupby('Continent')

# %%
df.groupby('Continent').groups
# Out:
# {'Africa': Int64Index([  2,   3,  17,  21,  25,  26,  28,  30,  31,  32,  36,  37,  38,
#               40,  46,  49,  51,  52,  54,  58,  59,  62,  67,  68,  86,  95,
#               96,  97, 102, 103, 106, 108, 109, 115, 116, 118, 123, 124, 138,
#              142, 144, 146, 147, 152, 153, 154, 157, 159, 165, 168, 171, 174,
#              186, 187],
#             dtype='int64'),
#  'Asia': Int64Index([  0,  11,  12,  18,  23,  27,  34,  72,  75,  76,  77,  78,  80,
#               83,  84,  85,  88,  89,  90,  91,  92,  94, 100, 104, 105, 113,
#              117, 119, 126, 127, 132, 135, 137, 143, 148, 156, 162, 163, 164,
#              166, 167, 172, 173, 176, 180, 183, 184, 185],
#             dtype='int64'),
#  'Europe': Int64Index([  1,   6,   8,   9,  14,  15,  20,  24,  41,  43,  44,  45,  53,
#               56,  57,  60,  61,  63,  73,  74,  79,  81,  93,  98,  99, 101,
#              107, 112, 114, 120, 125, 133, 134, 136, 145, 149, 150, 155, 160,
# ...

# %%
df.groupby('Continent').life_expectancy.median()
# Out:
# Continent
# Africa        52.1025
# Asia          70.4275
# Europe        75.5800
# N. America    70.5765
# Oceania       67.4955
# S. America    70.7660
# Name: life_expectancy, dtype: float64

# %%
df.Population.sum()
# Out:
# 6115042358

# %%
df.groupby('Continent').Population.sum()
# The thing on the left is called the INDEX
# The thing on the right is called the VALUES
# Out:
# Continent
# Africa         809892820
# Asia          3849172861
# Europe         596440013
# N. America     481999240
# Oceania         30272328
# S. America     347265096
# Name: Population, dtype: int64

# %%
# This is a SERIES, it only has an INDEX and VALUES
# it doesn't actually have columns to sort by
# we sort this with .sort_values(), which normally needs
# a column name, but since we don't have any, we dont' have to give it one
df.groupby('Continent').Population.sum().sort_values(ascending=False)
# Out:
# Continent
# Asia          3849172861
# Africa         809892820
# Europe         596440013
# N. America     481999240
# S. America     347265096
# Oceania         30272328
# Name: Population, dtype: int64

# %%
df.Continent.value_counts()
# Out:
# Africa        54
# Asia          48
# Europe        42
# N. America    22
# S. America    12
# Oceania       10
# Name: Continent, dtype: int64

# %%
df.Continent.value_counts(normalize=True) * 100
# Out:
# Africa        28.723404
# Asia          25.531915
# Europe        22.340426
# N. America    11.702128
# S. America     6.382979
# Oceania        5.319149
# Name: Continent, dtype: float64

# %%
df.head()
# Out:
#                Country   Continent  GDP_per_capita  life_expectancy  \
# 0          Afghanistan        Asia             663           54.863
# 1              Albania      Europe            4195           74.200
# 2              Algeria      Africa            5098           68.963
# 3               Angola      Africa            2446           45.234
# 4  Antigua and Barbuda  N. America           12738           73.544
#
#    Population
# 0    22856302
# 1     3071856
# 2    30533827
# 3    13926373
# 4       77656

# %%
df.GDP_per_capita * df.Population
# this works like a for loop - it goes row-by-row and calculates for you
# Out:
# 0         15153728226
# 1         12886435920
# 2        155661450046
# 3         34063908358
# 4           989182128
# 5        390394524839
# 6          6502871172
# 7        560384787591
# 8        256214821696
# 9         20544461359
# 10         6765011928
# 11        14049818895
# 12       139311695625
# 13         4007849802
# 14        59703160160
# 15       304659978960
# 16         1639601040
# 17         8518777670
# 18         1669227564
# 19        28194799712
# 20        21175970634
# 21        17767347975
# 22      1405170917672
# 23        15704268720
# 24        55298533306
# 25        12306306012
# 26         2823835721
# 27        12222903918
# 28        28267919007
# 29       995094659520
#             ...
# 158        2650284742
# 159        4277668472
# 160      253754781920
# 161      246475684488
# 162       62914881290
# 163      521855075000
# 164        6178979807
# 165       28115520986
# 166      352278751762
# 167        2276934127
# ...

# %%
# This doesn't work
#df.GDP = df.GDP_per_capita * df.Population
df['GDP'] = df.GDP_per_capita * df.Population
df.head()
# Out:
#                Country   Continent  GDP_per_capita  life_expectancy  \
# 0          Afghanistan        Asia             663           54.863
# 1              Albania      Europe            4195           74.200
# 2              Algeria      Africa            5098           68.963
# 3               Angola      Africa            2446           45.234
# 4  Antigua and Barbuda  N. America           12738           73.544
#
#    Population           GDP
# 0    22856302   15153728226
# 1     3071856   12886435920
# 2    30533827  155661450046
# 3    13926373   34063908358
# 4       77656     989182128

# %%
df.Continent == 'Africa'
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17      True
# 18     False
# 19     False
# 20     False
# 21      True
# 22     False
# 23     False
# 24     False
# 25      True
# 26      True
# 27     False
# 28      True
# 29     False
#        ...
# 158    False
# 159     True
# 160    False
# 161    False
# 162    False
# 163    False
# 164    False
# 165     True
# 166    False
# 167    False
# 168     True
# 169    False
# 170    False
# 171     True
# 172    False
# 173    False
# 174     True
# 175    False
# 176    False
# 177    False
# 178    False
# 179    False
# 180    False
# 181    False
# 182    False
# 183    False
# 184    False
# 185    False
# 186     True
# 187     True
# Name: Continent, Length: 188, dtype: bool

# %%
# wrap it in square brackets to get rows where this statement is true
# rename this as africa_df to make life easier
africa_df = df[df.Continent == 'Africa']
africa_df.head()
# Out:
#          Country Continent  GDP_per_capita  life_expectancy  Population  \
# 2        Algeria    Africa            5098           68.963    30533827
# 3         Angola    Africa            2446           45.234    13926373
# 17         Benin    Africa            1307           55.261     6517810
# 21      Botswana    Africa           10107           50.567     1757925
# 25  Burkina Faso    Africa            1001           50.589    12294012
#
#              GDP
# 2   155661450046
# 3    34063908358
# 17    8518777670
# 21   17767347975
# 25   12306306012

# %%
# multiple conditions
df[(df.Continent == 'Africa') & (df.life_expectancy > 60)]
# Out:
#                    Country Continent  GDP_per_capita  life_expectancy  \
# 2                  Algeria    Africa            5098           68.963
# 30              Cape Verde    Africa            2291           69.835
# 49                   Egypt    Africa            4629           68.632
# 97                   Libya    Africa            9139           71.872
# 109              Mauritius    Africa            8290           71.202
# 115                Morocco    Africa            3073           68.220
# 142  Sao Tome and Principe    Africa            1320           63.336
# 146             Seychelles    Africa           15230           71.771
# 171                Tunisia    Africa            5480           73.159
#
#      Population           GDP
# 2      30533827  155661450046
# 30       437238    1001712258
# 49     67648419  313144531551
# 97      5231189   47807836271
# 109     1196027    9915063830
# 115    28793236   88481614228
# 142      141010     186133200
# ...

# %%
df.groupby('Continent').life_expectancy.median().plot

# %%
# %matplotlib inline
# matplotlib is the graphing library, and we're telling it to do things inline

# %%
df.groupby('Continent').life_expectancy.median().plot()

# %%
# line graph is probably not the best for this
df.groupby('Continent').life_expectancy.median().plot(kind='bar')

# %%
# how about a horizontal bar graph?
df.groupby('Continent').life_expectancy.median().plot(kind='barh')

# %%
# let's do alphabetical order
df.groupby('Continent').life_expectancy.median().sort_values(ascending=False).plot(kind='barh')

# %%
df.head()
# Out:
#                Country   Continent  GDP_per_capita  life_expectancy  \
# 0          Afghanistan        Asia             663           54.863
# 1              Albania      Europe            4195           74.200
# 2              Algeria      Africa            5098           68.963
# 3               Angola      Africa            2446           45.234
# 4  Antigua and Barbuda  N. America           12738           73.544
#
#    Population           GDP
# 0    22856302   15153728226
# 1     3071856   12886435920
# 2    30533827  155661450046
# 3    13926373   34063908358
# 4       77656     989182128

# %%
df.plot(x='GDP_per_capita', y='life_expectancy', kind='scatter')
